# %%
import pandas as pd

# %%
df=pd.read_csv('data/Danh_gia.csv')
df.head()
# Out:
#    id  ma_khach_hang                                 noi_dung_binh_luan  \
# 0   1            443   SỬ DỤNG DỄ DÀNG, RẤT THOẢI MÁI, THƯ GIÃN TỘT ĐỘ.
# 1   2           1030      Sử dụng dễ dãng,rất thoải mái,thư giãn tột độ
# 2   3            689          Mình rất thích hasaki va sp tẩy trang này
# 3   4           2519  Sản phẩm có khả năng làm sạch tốt. Lớp trang đ...
# 4   5            402       Sữa rửa mặt tốt,sạch mụn,mịn da,đáng mua nha
#
#   ngay_binh_luan gio_binh_luan  so_sao  ma_san_pham
# 0     29/04/2023         17:06       5    308500015
# 1     30/04/2023         15:04       5    308500015
# 2     30/04/2023         18:34       5    422216594
# 3     17/07/2022         13:48       5    204100075
# 4     15/04/2023         23:04       5    422208977

# %%
df_test=df.tail(10)[['noi_dung_binh_luan']]
df_test
# Out:
#                                       noi_dung_binh_luan
# 21565  sp tốt,lành tính nhất trog các loại srm. nhưng...
# 21566                                                NaN
# 21567  Da khô bôi lên mặt cảm giác nhờn rít khó chịu,...
# 21568  hiệu quả tốt, dễ tán đều kem. nhưng hơi khó ch...
# 21569  sợ tốt thích hợp cho da dầu có mụn luôn ạk, e ...
# 21570  Dùng sp này bị ghiền luôn, hạt siêu mịn, mùi t...
# 21571  Mua nhiều lần ở đây rồi ạ. Sản phẩm ok, giá rẻ...
# 21572   Sản phẩm có một số hạn chế, không thực sự ưng ý.
# 21573  dùng kem này từ 2 năm trước, kem sáng da trắng...
# 21574  Chất đặt dùng rất hợp cho da khô e này thiên v...

# %%
df_test.to_csv('data/output.csv', index=False)

# %%
sampled_df = df.sample(n=10, random_state=42)

# %%
sampled_df
# Out:
#           id  ma_khach_hang  \
# 16728  16729           1574
# 20825  20826           1920
# 2150    2151            256
# 20648  20649           1162
# 5377    5378           2079
# 4877    4878           1975
# 5135    5136           2311
# 7019    7020           2519
# 14735  14736            795
# 2270    2271            121
#
#                                       noi_dung_binh_luan ngay_binh_luan  \
# 16728  mình sài được 3 ngày nên da mặt cũng chưa thấy...     31/05/2021
# 20825    Không có gì đáng chê nhưng cũng không xuất sắc.     17/11/2023
# 2150   sản phẩm nên mua cho hssv giá thành rẻ chất lư...       9/8/2021
# 20648  em này tạo lớp màng ẩm cho da nên nhìn bóng bó...     30/08/2023
# 5377                                     mình sài rất Ok     17/06/2019
# 4877   thấm nhanh,nâng tông,sau khi thoa 2 tiếng có v...      12/5/2023
# 5135    Sử dụng dễ dàng, rất thoải mái. Thư giãn tột độ.       5/5/2023
# ...
